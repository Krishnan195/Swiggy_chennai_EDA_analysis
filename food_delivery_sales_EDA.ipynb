# %%
# !pip install matplotlib.pyplot
# !pip install seaborn
# !pip install plotly.express
# Out:
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# Requirement already satisfied: seaborn in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: plotly.express in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: plotly>=4.1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (6.6.0)
# Requirement already satisfied: statsmodels>=0.9.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (0.14.6)
# Requirement already satisfied: scipy>=0.18 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (1.17.1)
# Requirement already satisfied: patsy>=0.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (1.0.2)
# Requirement already satisfied: numpy>=1.11 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly>=4.1.0->plotly.express) (2.17.0)
# Requirement already satisfied: packaging in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
##SWIGGY SALES ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_excel("D:/swiggy_sales_analysis/swiggy_data.xlsx")

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#        State       City Order Date           Restaurant Name  \
# 0  Karnataka  Bengaluru 2025-06-29  Anand Sweets & Savouries
# 1  Karnataka  Bengaluru 2025-04-03     Srinidhi Sagar Deluxe
# 2  Karnataka  Bengaluru 2025-01-15     Srinidhi Sagar Deluxe
# 3  Karnataka  Bengaluru 2025-04-17     Srinidhi Sagar Deluxe
# 4  Karnataka  Bengaluru 2025-03-13     Srinidhi Sagar Deluxe
#
#                Location     Category             Dish Name  Price (INR)  \
# 0  Rajarajeshwari Nagar        Snack  Butter Murukku-200gm        133.9
# 1               Kengeri  Recommended            Badam Milk         52.0
# 2               Kengeri  Recommended        Chow Chow Bath        117.0
# 3               Kengeri  Recommended           Kesari Bath         65.0
# 4               Kengeri  Recommended            Mix Raitha        130.0
#
#    Rating  Rating Count
# 0     4.0             0
# 1     4.5            25
# 2     4.7            48
# 3     4.6            65
# 4     4.0             0

# %%
df.tail()
# Out:
#          State     City Order Date Restaurant Name Location Category  \
# 197425  Sikkim  Gangtok 2025-01-25  Mama's Kitchen  Gangtok    Momos
# 197426  Sikkim  Gangtok 2025-07-02  Mama's Kitchen  Gangtok    Momos
# 197427  Sikkim  Gangtok 2025-03-25  Mama's Kitchen  Gangtok    Momos
# 197428  Sikkim  Gangtok 2025-03-26  Mama's Kitchen  Gangtok    Momos
# 197429  Sikkim  Gangtok 2025-03-27  Mama's Kitchen  Gangtok    Momos
#
#                                                 Dish Name  Price (INR)  \
# 197425  Soya cheese chilli momo                       ...        112.0
# 197426  Kurkure momo fried                            ...        140.0
# 197427                                Chilli cheese momo         126.0
# 197428                                   Veg Momos (8 Pc)         85.0
# 197429                                          Soya Momo        100.0
#
#         Rating  Rating Count
# 197425     4.4             0
# 197426     4.4             0
# 197427     4.4             0
# 197428     4.4             0
# 197429     4.4             0

# %%
### META DATA

# %%
print("No of Rows :", df.shape[0])
# Out:
# No of Rows : 197430

# %%
print("No of Fields :", df.shape[1])
# Out:
# No of Fields : 10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197430 entries, 0 to 197429
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   State            197430 non-null  object
#  1   City             197430 non-null  object
#  2   Order Date       197430 non-null  datetime64[ns]
#  3   Restaurant Name  197430 non-null  object
#  4   Location         197430 non-null  object
#  5   Category         197430 non-null  object
#  6   Dish Name        197430 non-null  object
#  7   Price (INR)      197430 non-null  float64
#  8   Rating           197430 non-null  float64
#  9   Rating Count     197430 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 15.1+ MB

# %%
### Data Types

# %%
df.dtypes
# Out:
# State                      object
# City                       object
# Order Date         datetime64[ns]
# Restaurant Name            object
# Location                   object
# Category                   object
# Dish Name                  object
# Price (INR)               float64
# Rating                    float64
# Rating Count                int64
# dtype: object

# %%
df.describe()
# Out:
#                           Order Date    Price (INR)         Rating  \
# count                         197430  197430.000000  197430.000000
# mean   2025-05-01 19:41:20.996808960     268.512920       4.341582
# min              2025-01-01 00:00:00       0.950000       1.500000
# 25%              2025-03-01 00:00:00     139.000000       4.300000
# 50%              2025-05-02 00:00:00     229.000000       4.400000
# 75%              2025-07-01 00:00:00     329.000000       4.500000
# max              2025-08-31 00:00:00    8000.000000       5.000000
# std                              NaN     219.338363       0.422585
#
#         Rating Count
# count  197430.000000
# mean       28.321805
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%        15.000000
# max       999.000000
# std        87.542593

# %%
###KPI'S

# %%
##Total Sales

# %%
total_sales= df["Price (INR)"].sum()
print("Total_Sales :" ,round(total_sales,2))
# Out:
# Total_Sales : 53012505.77

# %%
### AVERAGE RATING

# %%
Average_rating= df["Rating"].mean()
print("Avg_Rating :" , round(Average_rating,1))
# Out:
# Avg_Rating : 4.3

# %%
### Average Order Value

# %%
Average_order_value= df["Price (INR)"].mean()
print("Avg Order Value :" ,round(Average_order_value,2))
# Out:
# Avg Order Value : 268.51

# %%
### Ratings Count

# %%
Rating_Count= df["Rating Count"].sum()
print("Rating Count :" ,round(Rating_Count,2))
# Out:
# Rating Count : 5591574

# %%
###Total Orders

# %%
print("Total Orders :" ,len(df))
# Out:
# Total Orders : 197430

# %%
### Charts

# %%
### Monthly Sales Trends

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

df["YearMonth"] = df["Order Date"].dt.to_period("M").astype(str)

monthly_revenue = df.groupby("YearMonth")["Price (INR)"].sum().reset_index()

plt.figure()
plt.plot(monthly_revenue["YearMonth"],monthly_revenue["Price (INR)"])
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Total Sales (INR)")
plt.title("Monthly Sales Trend")
plt.tight_layout()
plt.show()

# %%
###Daily Sales Trends

# %%
df["DayName"] = pd.to_datetime(df["Order Date"]).dt.day_name()

daily_revenue = (
    df.groupby("DayName")["Price (INR)"].sum()
    .reindex(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"])

)

plt.figure(figsize=(10,5))
plt.bar(daily_revenue.index,daily_revenue.values)
plt.title("Daily Revenue Trend (Mon-Sat)")
plt.xlabel("Day")
plt.ylabel("Revenue (INR)")
plt.xticks(rotation=30)

plt.show()

# %%
### Total Sales By Food Type(Veg - Non Veg

# %%
non_veg_keywords = [
    "chicken", "egg", "fish", "mutton",
    "prawn", "briyani", "kabab", "kebab",
    "non-veg", "non veg"
]

df["Food Category"] = np.where(
    df["Dish Name"].str.lower().str.contains("|".join(non_veg_keywords), na=False),
    "Non-Veg",
    "Veg"
)

# %%
food_revenue = (
    df.groupby("Food Category")["Price (INR)"]
    .sum()
    .reset_index()
)

# %%
pip install plotly.express
# Out:
# Requirement already satisfied: plotly.express in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: plotly>=4.1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (6.6.0)
# Requirement already satisfied: statsmodels>=0.9.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (0.14.6)
# Requirement already satisfied: scipy>=0.18 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (1.17.1)
# Requirement already satisfied: patsy>=0.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (1.0.2)
# Requirement already satisfied: numpy>=1.11 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly>=4.1.0->plotly.express) (2.17.0)
# Requirement already satisfied: packaging in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
### Top 5 cities By sales

# %%
top_5_cities = (
    df.groupby("City")["Price (INR)"]
    .sum()
    .nlargest(5)
   .sort_values()
     .reset_index()
)

fig = px.bar(
    top_5_cities,
    x="Price (INR)",
    y="City",
    orientation="h",
    title="Top 5 Cities by Sale (INR)",
    color_discrete_sequence=["red"]
)

fig.show()
